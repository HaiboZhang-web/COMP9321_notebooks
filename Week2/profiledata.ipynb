# %%
pip install fg-data-profiling
# Out:
# Requirement already satisfied: fg-data-profiling in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (4.20.0)
# Requirement already satisfied: scipy<1.19.0,>=1.8 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (1.18.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<3.12,>=3.5 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from fg-data-profiling) (3.11.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (2.13.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (3.1.6)
# Requirement already satisfied: visions<0.9,>=0.7.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (0.8.2)
# Requirement already satisfied: numpy<2.6,>=1.22 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from fg-data-profiling) (2.5.1)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (4.70.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (0.15.0)
# Requirement already satisfied: typeguard<5,>=4 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (1.9.2)
# Requirement already satisfied: numba<0.68,>=0.60 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from fg-data-profiling) (0.67.0)
# Requirement already satisfied: PyWavelets in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from imagehash==4.3.2->fg-data-profiling) (1.10.0)
# Requirement already satisfied: pillow in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from imagehash==4.3.2->fg-data-profiling) (12.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from jinja2<3.2,>=3.1.6->fg-data-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (26.3)
# Requirement already satisfied: pyparsing>=3 in /Users/haibozhang/Library/Python/3.14/lib/python/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.50,>=0.49.0dev0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from numba<0.68,>=0.60->fg-data-profiling) (0.49.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2026.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from phik<0.13,>=0.12.5->fg-data-profiling) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pydantic<3,>=2->fg-data-profiling) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pydantic<3,>=2->fg-data-profiling) (2.46.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pydantic<3,>=2->fg-data-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pydantic<3,>=2->fg-data-profiling) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/homebrew/opt/certifi/lib/python3.14/site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from statsmodels<1,>=0.13.2->fg-data-profiling) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from statsmodels<1,>=0.13.2->fg-data-profiling) (1.2.2)
# Requirement already satisfied: attrs>=19.3.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (3.7)
# Requirement already satisfied: puremagic in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (2.2.0)
# Requirement already satisfied: shapely in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (2.1.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from formulaic>=1.1.0->statsmodels<1,>=0.13.2->fg-data-profiling) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from formulaic>=1.1.0->statsmodels<1,>=0.13.2->fg-data-profiling) (2.26.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from formulaic>=1.1.0->statsmodels<1,>=0.13.2->fg-data-profiling) (2.4.2rc1)
# Requirement already satisfied: cloudpickle>=3.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from joblib>=0.14.1->phik<0.13,>=0.12.5->fg-data-profiling) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib<3.12,>=3.5->fg-data-profiling) (1.17.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.9-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipywidgets) (9.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipywidgets) (5.16.1)
# Collecting widgetsnbextension~=4.0.16 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.16-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.17 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.17-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.53)
# Requirement already satisfied: psutil>=7 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.2)
# Requirement already satisfied: pure_eval in /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.9-py3-none-any.whl (140 kB)
# Using cached jupyterlab_widgets-3.0.17-py3-none-any.whl (217 kB)
# Using cached widgetsnbextension-4.0.16-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]
# Successfully installed ipywidgets-8.1.9 jupyterlab_widgets-3.0.17 widgetsnbextension-4.0.16
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import data_profiling
from data_profiling import ProfileReport
import pandas as pd

# %%
#raw_data = pd.read_csv("data.csv")
raw_data = pd.read_csv("cve.csv")
df = pd.DataFrame(raw_data)

# %%
#profile = ProfileReport(df,title="Grade")
profile = ProfileReport(df,title="CVE Exploration")

# %%
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%| | 0/12 [00:00<?, ?it/s, Describe variable: Unnamed: 6]
# Summarize dataset:  42%|▍| 5/12 [00:01<00:02,  3.16it/s, Describe variable: Unn
# Summarize dataset:  58%|▌| 7/12 [00:02<00:02,  1.83it/s, Describe variable: Unn
# 100%|████████████████████████████████████████████| 7/7 [00:02<00:00,  3.34it/s]
# Summarize dataset: 100%|████████████| 20/20 [00:03<00:00,  6.33it/s, Completed]
# Generate report structure: 100%|█████████████████| 1/1 [00:00<00:00,  1.50it/s]
# Render HTML: 100%|███████████████████████████████| 1/1 [00:00<00:00, 51.47it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.20.0&quot; name=generator&gt;&lt;meta content=https://github.com/Data-Centric-AI-Community/data-profiling name=url&gt;&lt;meta content=&quot;2026-09-23 01:35:21.489668&quot; name=date&gt;&lt;title&gt;CVE Exploration&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...
